# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# AbdulMuiz Shaikh
#
# In this Jupyter notebook, we will be building a real-life data science project on Bioinformatics. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 6.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for hERG**

# %%
# Target search for hERG
target = new_client.target
target_query = target.search('herg')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
#
#                                            pref_name  score  \
# 0  Voltage-gated inwardly rectifying potassium ch...   13.0
# 1      Melanin-concentrating hormone receptor 2/HERG   12.0
# 2  Voltage-gated inwardly rectifying potassium ch...    9.0
# 3                    Voltage-gated potassium channel    2.0
#
#    species_group_flag target_chembl_id  \
# 0               False        CHEMBL240
# 1               False    CHEMBL4106188
# 2               False    CHEMBL2363011
# 3               False    CHEMBL2362996
#
#                                    target_components        target_type  \
# 0  [{'accession': 'Q12809', 'component_descriptio...     SINGLE PROTEIN
# 1  [{'accession': 'Q12809', 'component_descriptio...  SELECTIVITY GROUP
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Voltage-gated inwardly rectifying potassium channel KCNH2* (zero entry)**

# %% [markdown]
# We will assign the zero entry (which corresponds to the target protein, *Voltage-gated inwardly rectifying potassium channel KCNH2*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL240'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Voltage-gated inwardly rectifying potassium channel KCNH2* (CHEMBL240) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res[:9999])

# %%
df
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None       305156                  []
# 1           None             None       305157                  []
# 2           None             None       305244                  []
# 3           None             None       305245                  []
# 4           None             None       306561                  []
# ...          ...              ...          ...                 ...
# 9994        None             None     16880541                  []
# 9995        None             None     16880542                  []
# 9996        None             None     16880543                  []
# 9997        None             None     16880544                  []
# 9998        None             None     16880545                  []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL841079                 Inhibition of hERG currents Kv11.1
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **hERG_bioactivity_data.csv**.

# %%
df.to_csv('hERG_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipython-input-3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None       305156                  []
# 1           None             None       305157                  []
# 2           None             None       305244                  []
# 3           None             None       305245                  []
# 4           None             None       306561                  []
# ...          ...              ...          ...                 ...
# 9994        None             None     16880541                  []
# 9995        None             None     16880542                  []
# 9996        None             None     16880543                  []
# 9997        None             None     16880544                  []
# 9998        None             None     16880545                  []
#
# ...

# %%
print(df2['standard_value'].isnull().sum())
print(df2['canonical_smiles'].isnull().sum())
# Out:
# 0
# 0

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL12713  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
# 2            CHEMBL1108  O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F...
# 3         CHEMBL2368925  O=C(O[C@@H]1C[C@@H]2C[C@H]3C[C@H](C1)N2CC3=O)c...
# 4            CHEMBL6966  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 5            CHEMBL1107  CCCCN(CCCC)CCC(O)c1cc2c(Cl)cc(Cl)cc2c2cc(C(F)(...
# ...                 ...                                                ...
# 9994      CHEMBL3920203  CC(C)S(=O)(=O)NCCN1CC2CN(C[C@H](O)COc3ccc(C#N)...
# 9995      CHEMBL3917472  CC(C)(C)NS(=O)(=O)CCCN1CC2CN(CCCOc3ccc(C#N)cc3...
# 9996      CHEMBL3980357  CC(C)(C)OC(=O)NCCN1CC2CN(CCNS(=O)(=O)c3ccc(F)c...
# 9997      CHEMBL3976526  O=S(=O)(NCCN1CC2CN(Cc3ccccc3)CC(C1)O2)c1ccc(F)cc1
# 9998      CHEMBL3905698  N#Cc1ccc(OCCCN2CC3CN(CCNS(=O)(=O)Cc4ccccc4)CC(...
#
#      standard_value
# 0              14.0
# 2              32.2
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('hERG_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL12713  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
# 1            CHEMBL1108  O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F...
# 2         CHEMBL2368925  O=C(O[C@@H]1C[C@@H]2C[C@H]3C[C@H](C1)N2CC3=O)c...
# 3            CHEMBL6966  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 4            CHEMBL1107  CCCCN(CCCC)CCC(O)c1cc2c(Cl)cc(Cl)cc2c2cc(C(F)(...
# ...                 ...                                                ...
# 7175      CHEMBL3920203  CC(C)S(=O)(=O)NCCN1CC2CN(C[C@H](O)COc3ccc(C#N)...
# 7176      CHEMBL3917472  CC(C)(C)NS(=O)(=O)CCCN1CC2CN(CCCOc3ccc(C#N)cc3...
# 7177      CHEMBL3980357  CC(C)(C)OC(=O)NCCN1CC2CN(CCNS(=O)(=O)c3ccc(F)c...
# 7178      CHEMBL3976526  O=S(=O)(NCCN1CC2CN(Cc3ccccc3)CC(C1)O2)c1ccc(F)cc1
# 7179      CHEMBL3905698  N#Cc1ccc(OCCCN2CC3CN(CCNS(=O)(=O)Cc4ccccc4)CC(...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('hERG_bioactivity_data_curated.csv', index=False)

# %%
! zip hERG.zip *.csv
# Out:
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: hERG_bioactivity_data_curated.csv (deflated 83%)
#   adding: HERG_bioactivity_data_curated.csv (deflated 83%)
#   adding: hERG_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: HERG_bioactivity_data_raw.csv (deflated 91%)

# %% [markdown]
# ---
